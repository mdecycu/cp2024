# %%
from cmsimde import flaskapp
from gevent.pywsgi import WSGIServer

#flaskapp.app.run(host="0.0.0.0", debug=True)
http_server = WSGIServer(('2001:288:6004:17:10ff::2', 8080), flaskapp.app)
http_server.serve_forever()
# Out:
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:02] "GET / HTTP/1.1" 302 396 0.114192
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /get_page/About HTTP/1.1" 200 6526 0.241580
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/cmsimply.css HTTP/1.1" 200 4343 0.001953
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/syntaxhighlighter/shCore.js HTTP/1.1" 200 16521 0.000977
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/syntaxhighlighter/shBrushJScript.js HTTP/1.1" 200 2034 0.000976
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/syntaxhighlighter/shBrushJava.js HTTP/1.1" 200 2490 0.000967
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/syntaxhighlighter/shBrushHaxe.js HTTP/1.1" 200 2840 0.000975
# 2001:288:6004:17:10ff::2 - - [2024-09-01 19:42:03] "GET /static/syntaxhighlighter/shBrushPython.js HTTP/1.1" 200 2835 0.001950
# ...
